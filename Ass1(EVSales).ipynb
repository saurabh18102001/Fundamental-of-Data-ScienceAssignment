# %% [markdown]
# NAME : Saurabh Pal
#
# COURSE : Msc.IT
#
# SUBJECT : FDS(Fundamental of Data Science)
#
# ASSIGNMENT 1(EV.csv)
#
# EV Sales

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('IEA Global EV Data 2024.csv')
df.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 1  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 2  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0    0.00039
# 1    0.00650
# 2   49.00000
# 3   49.00000
# 4  220.00000

# %%
df.tail(10)
# Out:
#       region          category           parameter    mode  \
# 12644  World  Projection-STEPS      EV sales share    Vans
# 12645  World  Projection-STEPS      EV sales share  Trucks
# 12646  World  Projection-STEPS      EV stock share   Buses
# 12647  World  Projection-STEPS      EV sales share   Buses
# 12648  World  Projection-STEPS      EV stock share    Vans
# 12649  World  Projection-STEPS      EV sales share    Cars
# 12650  World  Projection-STEPS      EV stock share    Cars
# 12651  World    Projection-APS  EV charging points      EV
# 12652  World    Projection-APS  EV charging points      EV
# 12653  World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain  year             unit       value
# 12644                       EV  2035          percent        41.0
# 12645                       EV  2035          percent        22.0
# 12646                       EV  2035          percent        20.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12654 entries, 0 to 12653
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      12654 non-null  object
#  1   category    12654 non-null  object
#  2   parameter   12654 non-null  object
#  3   mode        12654 non-null  object
#  4   powertrain  12654 non-null  object
#  5   year        12654 non-null  int64
#  6   unit        12654 non-null  object
#  7   value       12654 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 791.0+ KB

# %%
df.shape
# Out:
# (12654, 8)

# %% [markdown]
# 2. Identify and drop columns and missing values.

# %%
df.isna().sum()
# Out:
# region        0
# category      0
# parameter     0
# mode          0
# powertrain    0
# year          0
# unit          0
# value         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# region        0
# category      0
# parameter     0
# mode          0
# powertrain    0
# year          0
# unit          0
# value         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# region        0
# category      0
# parameter     0
# mode          0
# powertrain    0
# year          0
# unit          0
# value         0
# dtype: int64

# %% [markdown]
# 3. Identify unique values from given dataset for each column.

# %%
df.nunique()
# Out:
# region          54
# category         3
# parameter        8
# mode             5
# powertrain       6
# year            17
# unit             6
# value         1032
# dtype: int64

# %% [markdown]
# 7. Find out minimum and maximum price values and name of the product.

# %%
df[df['value'] == df['value'].max()][['category','value']]
# Out:
#              category        value
# 12609  Projection-APS  440000000.0

# %%
df[df['value'] == df['value'].min()][['category','value']]
# Out:
#         category     value
# 8359  Historical  0.000001

# %% [markdown]
# 8. Identify top three product categories

# %%
df.groupby('category')['value'].sum().sort_values(ascending=False).head(3)
# Out:
# category
# Projection-APS      2.582669e+09
# Projection-STEPS    2.383760e+09
# Historical          4.415641e+08
# Name: value, dtype: float64

# %% [markdown]
# 10. Find average unit price of the products.

# %%
df['value'].mean()
# Out:
# 427374.1734977358
