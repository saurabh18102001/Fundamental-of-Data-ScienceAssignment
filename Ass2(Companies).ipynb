# %% [markdown]
# NAME : Saurabh Pal
#
# COURSE : Msc.IT
#
# SUBJECT : FDS(Fundamental of Data Science)
#
# ASSIGNMENT 2(Ambition Box.csv)
#
# COMPANIES

# %%
import pandas as pd

# %%
df = pd.read_csv('Ambition Box.csv')

# %%
#Import dataset to pandas data-frame and identify dataset attributes.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4468 entries, 0 to 4467
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      4468 non-null   int64
#  1   name            4468 non-null   object
#  2   rating          4468 non-null   float64
#  3   review          4468 non-null   object
#  4   company_type    4466 non-null   object
#  5   Head_Quarters   4454 non-null   object
#  6   Company_Age     4416 non-null   object
#  7   No_of_Employee  3793 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 279.4+ KB

# %%
df.head()
#
# Out:
#    Unnamed: 0        name  rating           review company_type  \
# 0           0         TCS     3.9  (26.3k Reviews)       Public
# 1           1   Accenture     4.0  (20.5k Reviews)       Public
# 2           2   Cognizant     3.9  (18.7k Reviews)      Private
# 3           3  ICICI Bank     4.0  (18.5k Reviews)       Public
# 4           4   HDFC Bank     4.0  (16.2k Reviews)       Public
#
#                    Head_Quarters   Company_Age                No_of_Employee
# 0  Mumbai,Maharashtra + 203 more  53 years old     1 Lakh+ employees (India)
# 1       Dublin,Dublin + 119 more  32 years old     1 Lakh+ employees (India)
# 2   Teaneck,New Jersey + 66 more  27 years old     1 Lakh+ employees (India)
# 3  Mumbai,Maharashtra + 896 more  27 years old  50k-1 Lakh employees (India)
# 4  Mumbai,Maharashtra + 955 more  27 years old     1 Lakh+ employees (India)

# %%
#Find out how many unique companies are there.
df["name"].unique()
for i in df["name"].unique():
    print(i)
# Out:
# TCS
# Accenture
# Cognizant
# ICICI Bank
# HDFC Bank
# Wipro
# Capgemini
# HCL Technologies
# Infosys
# Tech Mahindra
# Genpact
# Axis Bank
# Vodafone Idea
# L&T
# Reliance jio
# IBM
# Concentrix Corpora...
# Amazon
# HDB Financial Serv...
# Kotak Mahindra Ban...
# Tata Motors
# Bharti Airtel
# Teleperformance
# Reliance Industrie...
# Deloitte
# Mahindra & Mahindr...
# IndusInd Bank
# Hinduja Global Sol...
# Samsung
# WNS
# Maruti Suzuki
# Reliance Retail
# Indian Army
# DXC Technology
# Infosys BPM
# Ericsson
# Bajaj Finserv
# HSBC
# Startek
# Ernst & Young
# Dr. Reddy's
# Jana Small Finance...
# Conneqt Business S...
# Cipla Pharmaceutic...
# ICICI Prudential L...
# Sutherland Global ...
# Mphasis
# Bajaj Allianz Life...
# Home Credit Financ...
# Lupin
# IDFC FIRST Bank
# Yes Bank
# Intelenet Global S...
# Asian Paints
# HDFC LIFE
# Hewlett-Packard En...
# Reliance Communica...
# Zydus Cadila
# NTT DATA
# OPPO
# Future Group
# Bajaj Finance
# Hindustan Unilever...
# ITC
# ...

# %%
df["name"].nunique()
# Out:
# 4332

# %%
df["company_type"].nunique()
# Out:
# 565

# %%
df["company_type"].unique()
# Out:
# array(['Public', 'Private', 'New Delhi,Delhi + 247 more',
#        'Bangalore/Bengaluru,Karnataka + 32 more',
#        'Mumbai,Maharashtra + 43 more', 'Mumbai,Maharashtra + 128 more',
#        'Mumbai,Maharashtra + 349 more', 'Bengaluru + 29 more',
#        'Partnership', 'Gurgaon/Gurugram,Haryana + 229 more',
#        'Amstelveen,North Holland + 42 more',
#        'Canonsburg,Pennsylvania + 54 more', 'Bangalore + 56 more',
#        'Mumbai,Maharashtra + 260 more', 'Chennai + 16 more',
#        'Columbus,Indiana + 70 more', 'Mumbai,Maharashtra + 33 more',
#        'Kochi/Cochin,Kerala + 286 more', 'Delhi/NCR,New Delhi + 45 more',
#        'Mumbai,Maharashtra + 138 more', 'Mumbai,Maharashtra + 236 more',
#        'Chennai,Tamil Nadu + 52 more', 'Mumbai,Maharashtra + 151 more',
#        'Vadodara/Baroda,Gujarat + 17 more', 'JV',
#        'Chennai,Tamil Nadu + 47 more',
#        'Hyderabad/Secunderabad,Telangana + 88 more',
#        'Mumbai,Maharashtra + 60 more',
# ...

# %%
#Find out total companies as per their categories and plot pie chart.
df["company_type"].value_counts().head(6)
# Out:
# company_type
# Private              2694
# Public               1070
# JV                     14
# Partnership             7
# Govt Organisation       6
# LLP                     6
# Name: count, dtype: int64

# %%
#Find out top 5 companies with highest rating and plot graph for the same.
df[['name', 'rating']].sort_values(by='rating', ascending=False).head(5)
# Out:
#                        name  rating
# 2314        Exotic Learning     5.0
# 3739  Bluestream Softwar...     5.0
# 860        Glorious Insight     5.0
# 1856              Appsierra     5.0
# 2297                   ACTE     5.0

# %%
# Find out oldest and newset 5 companies.

df['Company_Age'] = df['Company_Age'].str.replace('old', '')
df.head()
# Out:
#    Unnamed: 0        name  rating           review company_type  \
# 0           0         TCS     3.9  (26.3k Reviews)       Public
# 1           1   Accenture     4.0  (20.5k Reviews)       Public
# 2           2   Cognizant     3.9  (18.7k Reviews)      Private
# 3           3  ICICI Bank     4.0  (18.5k Reviews)       Public
# 4           4   HDFC Bank     4.0  (16.2k Reviews)       Public
#
#                    Head_Quarters Company_Age                No_of_Employee
# 0  Mumbai,Maharashtra + 203 more   53 years      1 Lakh+ employees (India)
# 1       Dublin,Dublin + 119 more   32 years      1 Lakh+ employees (India)
# 2   Teaneck,New Jersey + 66 more   27 years      1 Lakh+ employees (India)
# 3  Mumbai,Maharashtra + 896 more   27 years   50k-1 Lakh employees (India)
# 4  Mumbai,Maharashtra + 955 more   27 years      1 Lakh+ employees (India)

# %%
df[["name","Company_Age"]].sort_values(by='Company_Age', ascending=False).head(5)
# Out:
#                        name Company_Age
# 2017     Cooper Corporation   99 years
# 586            GAMMON INDIA   99 years
# 4125  University of Delh...   99 years
# 783                   Valeo   98 years
# 1873                 Mikuni   98 years

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# name                0
# rating              0
# review              0
# company_type        2
# Head_Quarters      14
# Company_Age        52
# No_of_Employee    675
# dtype: int64

# %%
#Identify locations which are having highest recruiters.
#Identify locations which are having lowest recruiters.
#Which company does have lowest staff?
df.sort_values(by='No_of_Employee', ascending=False).head(5)[['name','No_of_Employee']]
# Out:
#                       name            No_of_Employee
# 193  Standard Chartered...  5k-10k employees (India)
# 147          L & T Finance  5k-10k employees (India)
# 638       Manipal Hospital  5k-10k employees (India)
# 133                 Sodexo  5k-10k employees (India)
# 938  Power Grid Corpora...  5k-10k employees (India)
